# %% [markdown]
# # List (Creation, Modification and Access):

# %% [markdown]
# 1. List Creation:

# %%
#a. Create a list named age_list with five integer elements. For eg,. [24,25,26,27,28]

age_list = [24,25, 26, 27, 28]
print(age_list)
print(type(age_list))  #confirming its "list"

#b. Create a list named name_list with five string elements
name_list= ["jyo","sita","mary","ruby","luka"]
print(name_list)
print(type(name_list)) #confirming its "list"
# Out:
# [24, 25, 26, 27, 28]
# <class 'list'>
# ['jyo', 'sita', 'mary', 'ruby', 'luka']
# <class 'list'>

# %% [markdown]
# 2. List Operations / Modifications:

# %%
#a. Append the string "Yazhini" to name_list.
name_list.append("Yazhini")
print(name_list)

#b. Insert the element 30 at index 2 in age_list.
age_list.insert(2,30)
print(age_list)

#c. Remove the element "Yazhini" from name_list.
name_list.remove("Yazhini")
print(name_list)

#d. Pop the last element from age_list.
age_list.pop()
print(age_list)

#e. Extend the age_list with additional ages [29, 30, 26].
age_list.extend([29, 30, 26])
print(age_list)

#f. Sort age_list in descending order.
age_list.sort(reverse="true")
print(age_list)

#g. Find Max age, Min age and sum of all ages from age_list.
print("max age =",max(age_list))
print("min age =",min(age_list))
print("sum of all ages =",sum(age_list))
# Out:
# ['jyo', 'sita', 'mary', 'ruby', 'luka', 'Yazhini']
# [24, 25, 30, 26, 27, 28]
# ['jyo', 'sita', 'mary', 'ruby', 'luka']
# [24, 25, 30, 26, 27]
# [24, 25, 30, 26, 27, 29, 30, 26]
# [30, 30, 29, 27, 26, 26, 25, 24]
# max age = 30
# min age = 24
# sum of all ages = 217

# %% [markdown]
# 3. Accessing List Elements:

# %%
#a. Print the first element of name_list.
print(name_list[0])

#b. Print the last element of name_list.
print(name_list[-1])

#c. Print the elements from index 2 to index 4 in name_list.
print(name_list[2:5])

#d. Print the elements of name_list in reverse order.
print(name_list[::-1])
# Out:
# jyo
# luka
# ['mary', 'ruby', 'luka']
# ['luka', 'ruby', 'mary', 'sita', 'jyo']

# %% [markdown]
# # Dictionary (Creation, Modification and Access):

# %%
#a. Create a dictionary named student_marks that maps the names of five
#students to their marks (use scale of from 0 to 100).

student_marks={"lara":45,"luna":66,"zoey":98,"ewa":72,"john":84}
print(student_marks)
print(type(student_marks)) #confirming its "dictionary"

#b. Access and print the mark of a specific student, of your choice.
print(student_marks["zoey"])

#c. Add a new student "Janani" with a mark of 80 to the student_marks dictionary.
student_marks["janani"]=80
print(student_marks)

#d. Update the mark of any one older student to 82.
student_marks["ewa"]=82
print(student_marks)

#e. Use the keys(), values(), and items() methods to print all keys, values, and
#key-value pairs in the student_marks dictionary.

print(student_marks.keys())
print(student_marks.values())
print(student_marks.items())
# Out:
# {'lara': 45, 'luna': 66, 'zoey': 98, 'ewa': 72, 'john': 84}
# <class 'dict'>
# 98
# {'lara': 45, 'luna': 66, 'zoey': 98, 'ewa': 72, 'john': 84, 'janani': 80}
# {'lara': 45, 'luna': 66, 'zoey': 98, 'ewa': 82, 'john': 84, 'janani': 80}
# dict_keys(['lara', 'luna', 'zoey', 'ewa', 'john', 'janani'])
# dict_values([45, 66, 98, 82, 84, 80])
# dict_items([('lara', 45), ('luna', 66), ('zoey', 98), ('ewa', 82), ('john', 84), ('janani', 80)])

# %% [markdown]
# # Sets (Operations):

# %%
'''a. Create a set called my_set with following values:
['a','e','i','o','u','a','a','i']
Analyse the output and provide explanation for the same.'''

my_set={'a','e','i','o','u','a','a','i'}
print(my_set)
print(type(my_set)) #confirming its "set"
#Set only provide unique values and remove duplicates if found.

#b. Attempt to change the value of my_set[4] = 's'. If code throws an error, provide
#an explanation.

my_set[4]='s'
#It has thrown error because set doesnt promote indexing or modifications within the sequence.
# Out:
# {'e', 'o', 'u', 'i', 'a'}
# <class 'set'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_37653/2209417274.py in <cell line: 0>()
#      11 #an explanation.
#      12
# ---> 13 my_set[4]='s'
#      14 #It has thrown error because set doesnt promote indexing or modifications within the sequence.
#      15
#
# TypeError: 'set' object does not support item assignment

# %%
#c. Create two sets:
#set1 with values: {1, 3, 5, 7, 9}
#set2 with values: {2, 3, 5, 8, 10}

set1={1, 3, 5, 7, 9}
print(set1)
print(type(set1)) #confirming its "set"

set2={2, 3, 5, 8, 10}
print(set2)
print(type(set2)) #confirming its "set"

#d. Compute and print the union and intersection of set1 and set2.

print(set1.union(set2))
print(set1.intersection(set2))
# Out:
# {1, 3, 5, 7, 9}
# <class 'set'>
# {2, 3, 5, 8, 10}
# <class 'set'>
# {1, 2, 3, 5, 7, 8, 9, 10}
# {3, 5}

# %% [markdown]
# Operators & Conditional Statements :
# # (IF, ELIF, ELSE)

# %%
# 1. Prompt user for input. Score range should be from 0 to 10 (both inclusive).
score = int(input("Enter your score (0 to 10): "))

# 2. Find the performance category based on the input score using the given criteria
if score > 7:
    # a. Above Average: Score greater than 7
    category = "Above Average"
    message = "Great job! You are performing really well, keep it up!"
elif score >= 4 and score <= 7:
    # b. Average: Score between 4 and 7 (both inclusive)
    category = "Average"
    message = "Good effort! Keep practicing, there's room for improvement."
else:
    # c. Below Average: Score lesser than 4
    category = "Below Average"
    message = "Need to improve your performance, consistent practice will lead to better results."

# 3. Output: Print the Performance category
print(category + ":", message)
# Out:
# Enter your score (0 to 10): 8
# Above Average: Great job! You are performing really well, keep it up!
